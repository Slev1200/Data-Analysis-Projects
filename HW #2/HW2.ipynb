# %%
from matplotlib import pyplot as plt
import csv
import json
import numpy as np
from scipy.stats import norm
from scipy.stats import bernoulli
from scipy.stats import binom
import random
from collections import Counter
from collections import defaultdict

def jprint(data):
    print(json.dumps(data, indent=4))

data=[]
with open('input.csv', encoding="utf-8") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        row["Temperature(F)"]=float(row["Temperature(F)"])
        row["Humidity(%)"]=float(row["Humidity(%)"])
        row["Pressure(in)"]=float(row["Pressure(in)"])
        row["Visibility(mi)"]=float(row["Visibility(mi)"])
        row["Severity"]=int(row["Severity"])
        data.append(row)
    jprint(data)

test=[]
with open('test.csv', encoding="utf-8") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        row["Temperature(F)"]=float(row["Temperature(F)"])
        row["Visibility(mi)"]=float(row["Visibility(mi)"])
        row["Severity"]=int(row["Severity"])
        test.append(row)
# Out:
# [
#     {
#         "ID": "A-1000199",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 96.54379516575581,
#         "Humidity(%)": 67.04924289422331,
#         "Pressure(in)": 31.21462071903163,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1001335",
#         "Severity": 3,
#         "State": "KY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 86.0,
#         "Humidity(%)": 49.0,
#         "Pressure(in)": 29.97,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1001497",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 46.0,
#         "Pressure(in)": 30.08,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1003704",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 85.0,
#         "Humidity(%)": 65.0,
#         "Pressure(in)": 30.15,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1004487",
#         "Severity": 2,
#         "State": "IL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 79.67103575401892,
#         "Humidity(%)": 44.64103053995636,
#         "Pressure(in)": 29.85,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1005634",
#         "Severity": 2,
#         "State": "PA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 81.0,
#         "Humidity(%)": 29.0,
#         "Pressure(in)": 29.95,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1006127",
#         "Severity": 2,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 92.0,
#         "Humidity(%)": 71.0,
#         "Pressure(in)": 29.77,
#         "Visibility(mi)": 7.0,
#         "Crossing": "True",
#         "Stop": "True",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-100639",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 93.68357432668994,
#         "Humidity(%)": 68.40298316382447,
#         "Pressure(in)": 31.58638700835162,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1006627",
#         "Severity": 2,
#         "State": "MN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 86.34264602474023,
#         "Humidity(%)": 45.140631056064954,
#         "Pressure(in)": 29.84,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1007235",
#         "Severity": 2,
#         "State": "CO",
#         "Timezone": "US/Mountain",
#         "Temperature(F)": 66.31276920907587,
#         "Humidity(%)": 45.0,
#         "Pressure(in)": 34.048044459120035,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1008305",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 70.0,
#         "Humidity(%)": 27.0,
#         "Pressure(in)": 30.17,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1008428",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 82.0,
#         "Humidity(%)": 61.0,
#         "Pressure(in)": 29.77,
#         "Visibility(mi)": 10.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1008779",
#         "Severity": 3,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 88.0,
#         "Humidity(%)": 71.0,
#         "Pressure(in)": 29.92,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1009532",
#         "Severity": 3,
#         "State": "CO",
#         "Timezone": "US/Mountain",
#         "Temperature(F)": 97.52106278347338,
#         "Humidity(%)": 70.0,
#         "Pressure(in)": 35.03981907662328,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1009736",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 84.41610464043494,
#         "Humidity(%)": 37.52971942428261,
#         "Pressure(in)": 31.434423991650775,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1009874",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 87.06728620656995,
#         "Humidity(%)": 67.27180465875608,
#         "Pressure(in)": 31.885953226369196,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1010816",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 76.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 29.66,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1011694",
#         "Severity": 2,
#         "State": "TN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 82.88037766452196,
#         "Humidity(%)": 42.71659831631426,
#         "Pressure(in)": 29.82,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1012471",
#         "Severity": 2,
#         "State": "PA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1012717",
#         "Severity": 2,
#         "State": "TN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 80.9053670650464,
#         "Humidity(%)": 52.61021317628307,
#         "Pressure(in)": 30.1,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1013749",
#         "Severity": 3,
#         "State": "MA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 87.0,
#         "Humidity(%)": 46.0,
#         "Pressure(in)": 30.1,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1014178",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 70.0,
#         "Humidity(%)": 40.0,
#         "Pressure(in)": 29.9,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1015056",
#         "Severity": 2,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 78.19297392053153,
#         "Humidity(%)": 39.9257237445562,
#         "Pressure(in)": 29.57,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1015536",
#         "Severity": 2,
#         "State": "WA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 81.76993358665246,
#         "Humidity(%)": 55.618540260420936,
#         "Pressure(in)": 31.982833498104497,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1016289",
#         "Severity": 2,
#         "State": "OH",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 83.0,
#         "Humidity(%)": 64.0,
#         "Pressure(in)": 29.76,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1017600",
#         "Severity": 2,
#         "State": "TN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 78.91056773243189,
#         "Humidity(%)": 25.94100252715278,
#         "Pressure(in)": 30.26,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1019330",
#         "Severity": 3,
#         "State": "MO",
#         "Timezone": "US/Central",
#         "Temperature(F)": 93.40739959710164,
#         "Humidity(%)": 39.86675090212573,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1019478",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 88.219440929812,
#         "Humidity(%)": 58.28578933097879,
#         "Pressure(in)": 30.03,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1020014",
#         "Severity": 2,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 90.0325429155577,
#         "Humidity(%)": 50.64161513779428,
#         "Pressure(in)": 30.17,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1020805",
#         "Severity": 3,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 49.0,
#         "Pressure(in)": 29.94,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1021183",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 84.0,
#         "Humidity(%)": 52.0,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1021202",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 59.0,
#         "Pressure(in)": 30.25,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1021375",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 82.0,
#         "Humidity(%)": 57.0,
#         "Pressure(in)": 29.9,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1021518",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 58.0,
#         "Pressure(in)": 29.97,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-102274",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 84.74312598294719,
#         "Humidity(%)": 56.28751299970888,
#         "Pressure(in)": 31.11334608202709,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1023455",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 61.0,
#         "Pressure(in)": 30.08,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1024367",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 80.96051092192249,
#         "Humidity(%)": 45.21819192834659,
#         "Pressure(in)": 30.17,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1025276",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 81.80823667561188,
#         "Humidity(%)": 31.71650216982458,
#         "Pressure(in)": 31.59835387493319,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1025780",
#         "Severity": 3,
#         "State": "MN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 85.39637004740243,
#         "Humidity(%)": 53.63060551787295,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1027302",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 76.0,
#         "Humidity(%)": 64.0,
#         "Pressure(in)": 30.14,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1027982",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 70.87473448137017,
#         "Humidity(%)": 55.91251124508571,
#         "Pressure(in)": 30.1,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1028715",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 81.70423762725838,
#         "Humidity(%)": 35.283456166955084,
#         "Pressure(in)": 31.68824560034892,
#         "Visibility(mi)": 7.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-102959",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 70.94113147176324,
#         "Humidity(%)": 42.940119748702976,
#         "Pressure(in)": 31.164233276510178,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1030555",
#         "Severity": 2,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 85.04677529029367,
#         "Humidity(%)": 29.796095163779135,
#         "Pressure(in)": 29.75,
#         "Visibility(mi)": 9.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1030618",
#         "Severity": 2,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 74.38676481156071,
#         "Humidity(%)": 47.1242809346488,
#         "Pressure(in)": 29.91,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "True",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1031083",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 96.66195090159397,
#         "Humidity(%)": 34.08001356890123,
#         "Pressure(in)": 31.902283115223653,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1032952",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 69.0,
#         "Humidity(%)": 29.0,
#         "Pressure(in)": 29.99,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-103449",
#         "Severity": 1,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 74.03264245330016,
#         "Humidity(%)": 21.020468986429353,
#         "Pressure(in)": 32.20079005541529,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "True",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1034533",
#         "Severity": 2,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 46.0,
#         "Pressure(in)": 29.69,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1034995",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 88.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 30.15,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1035071",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 89.0,
#         "Humidity(%)": 41.0,
#         "Pressure(in)": 29.9,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1036908",
#         "Severity": 2,
#         "State": "PA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 31.0,
#         "Pressure(in)": 30.01,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1039499",
#         "Severity": 1,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 76.0,
#         "Humidity(%)": 26.0,
#         "Pressure(in)": 29.86,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1039697",
#         "Severity": 3,
#         "State": "OH",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 93.0,
#         "Humidity(%)": 49.0,
#         "Pressure(in)": 30.06,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1040794",
#         "Severity": 2,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 86.23209310033987,
#         "Humidity(%)": 54.066938025716055,
#         "Pressure(in)": 30.13,
#         "Visibility(mi)": 7.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1042470",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 79.0,
#         "Humidity(%)": 60.0,
#         "Pressure(in)": 29.82,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1042873",
#         "Severity": 2,
#         "State": "MO",
#         "Timezone": "US/Central",
#         "Temperature(F)": 70.2064857206772,
#         "Humidity(%)": 56.155799319233466,
#         "Pressure(in)": 29.65,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1043726",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 89.43128339884497,
#         "Humidity(%)": 57.16469856972141,
#         "Pressure(in)": 31.736757765478597,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1044236",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 78.0,
#         "Humidity(%)": 30.0,
#         "Pressure(in)": 30.24,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1044300",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 70.0,
#         "Humidity(%)": 36.0,
#         "Pressure(in)": 29.99,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1044851",
#         "Severity": 3,
#         "State": "RI",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 84.0,
#         "Humidity(%)": 68.0,
#         "Pressure(in)": 29.83,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-104545",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 85.061552104347,
#         "Humidity(%)": 41.582436352425944,
#         "Pressure(in)": 31.74894097696899,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1046156",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 73.0,
#         "Humidity(%)": 26.0,
#         "Pressure(in)": 29.77,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1047363",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 103.81217150781575,
#         "Humidity(%)": 52.33368569499572,
#         "Pressure(in)": 31.84163034301034,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1047595",
#         "Severity": 2,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 82.0,
#         "Humidity(%)": 59.0,
#         "Pressure(in)": 30.29,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1047749",
#         "Severity": 3,
#         "State": "KY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 91.0,
#         "Humidity(%)": 73.0,
#         "Pressure(in)": 30.09,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1048219",
#         "Severity": 2,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 76.0,
#         "Humidity(%)": 42.0,
#         "Pressure(in)": 30.51,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1048558",
#         "Severity": 2,
#         "State": "MO",
#         "Timezone": "US/Central",
#         "Temperature(F)": 71.66460499292526,
#         "Humidity(%)": 23.803903476179645,
#         "Pressure(in)": 29.88,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1049295",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 95.91874250121046,
#         "Humidity(%)": 65.07256013579533,
#         "Pressure(in)": 31.026896283471892,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1049906",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 74.0,
#         "Humidity(%)": 36.0,
#         "Pressure(in)": 30.07,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1051040",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 89.54446212468225,
#         "Humidity(%)": 47.314382663063235,
#         "Pressure(in)": 29.83,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-105110",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 96.54405322968302,
#         "Humidity(%)": 68.80052368282242,
#         "Pressure(in)": 31.538775523190303,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1051609",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 87.92767226252249,
#         "Humidity(%)": 55.3866529520378,
#         "Pressure(in)": 31.887719782242552,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1052539",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 43.0,
#         "Pressure(in)": 29.65,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1052783",
#         "Severity": 3,
#         "State": "MO",
#         "Timezone": "US/Central",
#         "Temperature(F)": 86.12033278344131,
#         "Humidity(%)": 66.91753744601849,
#         "Pressure(in)": 29.83,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1052831",
#         "Severity": 2,
#         "State": "NE",
#         "Timezone": "US/Central",
#         "Temperature(F)": 81.43012521916904,
#         "Humidity(%)": 32.37618973055836,
#         "Pressure(in)": 30.14,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1053001",
#         "Severity": 2,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 94.0725313890762,
#         "Humidity(%)": 40.77513143954754,
#         "Pressure(in)": 30.03,
#         "Visibility(mi)": 8.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1053624",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 89.32040206374346,
#         "Humidity(%)": 62.3210389761574,
#         "Pressure(in)": 31.85670662307416,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1055258",
#         "Severity": 3,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 91.01648485174691,
#         "Humidity(%)": 54.59646274636227,
#         "Pressure(in)": 29.91,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1055463",
#         "Severity": 3,
#         "State": "CO",
#         "Timezone": "US/Mountain",
#         "Temperature(F)": 87.49324128589603,
#         "Humidity(%)": 73.0,
#         "Pressure(in)": 34.91521565400871,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1055576",
#         "Severity": 2,
#         "State": "WA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 78.68978445761795,
#         "Humidity(%)": 29.800361228510383,
#         "Pressure(in)": 31.805545127969765,
#         "Visibility(mi)": 7.0,
#         "Crossing": "True",
#         "Stop": "True",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1056828",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 97.0,
#         "Humidity(%)": 71.0,
#         "Pressure(in)": 30.08,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-105864",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 93.10646115901837,
#         "Humidity(%)": 52.999720202017905,
#         "Pressure(in)": 31.785886341647554,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1058651",
#         "Severity": 2,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 74.60764534335564,
#         "Humidity(%)": 60.02737097417336,
#         "Pressure(in)": 30.16,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1059616",
#         "Severity": 3,
#         "State": "IN",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 92.0,
#         "Humidity(%)": 52.0,
#         "Pressure(in)": 29.99,
#         "Visibility(mi)": 3.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1060297",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 72.0,
#         "Humidity(%)": 46.0,
#         "Pressure(in)": 30.42,
#         "Visibility(mi)": 10.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1060300",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 76.0,
#         "Humidity(%)": 31.0,
#         "Pressure(in)": 30.27,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-106060",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 94.44113929402901,
#         "Humidity(%)": 52.68761861821199,
#         "Pressure(in)": 31.155808452677256,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-106090",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 76.05466362769003,
#         "Humidity(%)": 40.84129985971758,
#         "Pressure(in)": 31.807659086561753,
#         "Visibility(mi)": 10.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1062313",
#         "Severity": 3,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 88.0,
#         "Humidity(%)": 52.0,
#         "Pressure(in)": 30.21,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1062806",
#         "Severity": 2,
#         "State": "LA",
#         "Timezone": "US/Central",
#         "Temperature(F)": 86.0071261607973,
#         "Humidity(%)": 38.825011972740576,
#         "Pressure(in)": 29.75,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1062944",
#         "Severity": 2,
#         "State": "LA",
#         "Timezone": "US/Central",
#         "Temperature(F)": 79.38652840425036,
#         "Humidity(%)": 41.71947445791397,
#         "Pressure(in)": 30.18,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1063382",
#         "Severity": 2,
#         "State": "AZ",
#         "Timezone": "US/Mountain",
#         "Temperature(F)": 71.5431441677023,
#         "Humidity(%)": 59.0,
#         "Pressure(in)": 35.18872433606272,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-106500",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 81.87957036895736,
#         "Humidity(%)": 53.62675887768333,
#         "Pressure(in)": 31.33652823515619,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1065166",
#         "Severity": 3,
#         "State": "MN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 93.19852773350541,
#         "Humidity(%)": 48.07554266179345,
#         "Pressure(in)": 29.75,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1065610",
#         "Severity": 3,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 85.03187489307604,
#         "Humidity(%)": 35.903975929703975,
#         "Pressure(in)": 29.97,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1065695",
#         "Severity": 3,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 87.95271760243399,
#         "Humidity(%)": 35.745739489665816,
#         "Pressure(in)": 30.01,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1066976",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 83.0,
#         "Humidity(%)": 38.0,
#         "Pressure(in)": 29.67,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1067470",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 84.0,
#         "Humidity(%)": 67.0,
#         "Pressure(in)": 30.06,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1067500",
#         "Severity": 3,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 95.0,
#         "Humidity(%)": 53.0,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1067573",
#         "Severity": 4,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 91.0,
#         "Humidity(%)": 66.0,
#         "Pressure(in)": 30.92,
#         "Visibility(mi)": 3.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1067851",
#         "Severity": 3,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 88.96748427495167,
#         "Humidity(%)": 36.48391875692796,
#         "Pressure(in)": 30.15,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1068751",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 94.65562340106109,
#         "Humidity(%)": 36.98723926429953,
#         "Pressure(in)": 31.729199171806084,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1069063",
#         "Severity": 3,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 83.0,
#         "Humidity(%)": 51.0,
#         "Pressure(in)": 29.99,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1069222",
#         "Severity": 3,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 96.31561378816919,
#         "Humidity(%)": 72.30408707420327,
#         "Pressure(in)": 29.76,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1069742",
#         "Severity": 3,
#         "State": "PA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 99.0,
#         "Humidity(%)": 56.0,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1070136",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 74.37172723106747,
#         "Humidity(%)": 35.96214573339115,
#         "Pressure(in)": 31.074214738989664,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1070603",
#         "Severity": 2,
#         "State": "OH",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 84.0,
#         "Humidity(%)": 68.0,
#         "Pressure(in)": 30.12,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1070834",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 75.0,
#         "Humidity(%)": 36.0,
#         "Pressure(in)": 30.22,
#         "Visibility(mi)": 9.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1072064",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 78.75789658596477,
#         "Humidity(%)": 47.947749509952395,
#         "Pressure(in)": 31.573941361260975,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "True",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1072540",
#         "Severity": 2,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 85.0,
#         "Humidity(%)": 43.0,
#         "Pressure(in)": 30.24,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1073015",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 89.0,
#         "Humidity(%)": 40.0,
#         "Pressure(in)": 30.1,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1073110",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 92.0,
#         "Humidity(%)": 65.0,
#         "Pressure(in)": 30.11,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1073980",
#         "Severity": 3,
#         "State": "TN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 88.22531723901028,
#         "Humidity(%)": 51.52282254694141,
#         "Pressure(in)": 29.68,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1074272",
#         "Severity": 2,
#         "State": "NV",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 76.53629785125734,
#         "Humidity(%)": 39.923767883226176,
#         "Pressure(in)": 31.11904655048995,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-107445",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 86.07572950158745,
#         "Humidity(%)": 41.94196664707613,
#         "Pressure(in)": 32.01376206313091,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1075633",
#         "Severity": 3,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 93.0,
#         "Humidity(%)": 48.0,
#         "Pressure(in)": 29.84,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1076688",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 77.31542655994045,
#         "Humidity(%)": 45.83449836295014,
#         "Pressure(in)": 31.47402135122074,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1077001",
#         "Severity": 2,
#         "State": "MI",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 83.0,
#         "Humidity(%)": 56.0,
#         "Pressure(in)": 29.42,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1077698",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 98.0,
#         "Humidity(%)": 48.0,
#         "Pressure(in)": 29.76,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1078247",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 78.16279830639675,
#         "Humidity(%)": 24.99561608693881,
#         "Pressure(in)": 30.2,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1078521",
#         "Severity": 2,
#         "State": "AL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 83.79575377086805,
#         "Humidity(%)": 60.37963535054381,
#         "Pressure(in)": 30.01,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-108008",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 88.01021705519499,
#         "Humidity(%)": 47.650165703636475,
#         "Pressure(in)": 31.68577243950662,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-1083409",
#         "Severity": 3,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 85.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 30.03,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1083522",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 29.98,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-1083923",
#         "Severity": 2,
#         "State": "MO",
#         "Timezone": "US/Central",
#         "Temperature(F)": 91.84915598540906,
#         "Humidity(%)": 55.042958598243885,
#         "Pressure(in)": 30.07,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
# ...
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-969770",
#         "Severity": 4,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 100.0,
#         "Humidity(%)": 78.0,
#         "Pressure(in)": 30.99,
#         "Visibility(mi)": 2.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-97037",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 89.63029593756976,
#         "Humidity(%)": 40.428050166989976,
#         "Pressure(in)": 31.72169182826121,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-970909",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 82.88420327197433,
#         "Humidity(%)": 40.39124095225101,
#         "Pressure(in)": 31.88776074637254,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-970940",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 81.65510712897996,
#         "Humidity(%)": 30.84698681406131,
#         "Pressure(in)": 31.74464867644638,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-971466",
#         "Severity": 2,
#         "State": "OH",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 70.0,
#         "Humidity(%)": 49.0,
#         "Pressure(in)": 29.92,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-972776",
#         "Severity": 2,
#         "State": "TX",
#         "Timezone": "US/Central",
#         "Temperature(F)": 87.66149970498373,
#         "Humidity(%)": 66.94813029681455,
#         "Pressure(in)": 30.03,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-973258",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 80.49215251525371,
#         "Humidity(%)": 59.88371282180045,
#         "Pressure(in)": 31.97568765704326,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-973709",
#         "Severity": 2,
#         "State": "PA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 73.0,
#         "Humidity(%)": 35.0,
#         "Pressure(in)": 29.87,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-974051",
#         "Severity": 2,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 75.0,
#         "Humidity(%)": 41.0,
#         "Pressure(in)": 29.92,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-976295",
#         "Severity": 2,
#         "State": "NC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 54.0,
#         "Pressure(in)": 29.9,
#         "Visibility(mi)": 8.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-976619",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 79.0,
#         "Humidity(%)": 66.0,
#         "Pressure(in)": 30.08,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-978250",
#         "Severity": 3,
#         "State": "MA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 82.0,
#         "Humidity(%)": 68.0,
#         "Pressure(in)": 29.97,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-978499",
#         "Severity": 2,
#         "State": "OH",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 87.0,
#         "Humidity(%)": 34.0,
#         "Pressure(in)": 30.23,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-978603",
#         "Severity": 3,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 86.0,
#         "Humidity(%)": 43.0,
#         "Pressure(in)": 30.04,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-979022",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 93.0,
#         "Humidity(%)": 53.0,
#         "Pressure(in)": 29.98,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-979174",
#         "Severity": 3,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 88.0,
#         "Humidity(%)": 63.0,
#         "Pressure(in)": 30.21,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-982091",
#         "Severity": 2,
#         "State": "LA",
#         "Timezone": "US/Central",
#         "Temperature(F)": 85.92446380825136,
#         "Humidity(%)": 46.614255765656004,
#         "Pressure(in)": 29.64,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-982163",
#         "Severity": 2,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 90.39166041610109,
#         "Humidity(%)": 48.85660564827715,
#         "Pressure(in)": 29.95,
#         "Visibility(mi)": 8.0,
#         "Crossing": "True",
#         "Stop": "True",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-983828",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 90.0,
#         "Humidity(%)": 54.0,
#         "Pressure(in)": 29.91,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-984323",
#         "Severity": 3,
#         "State": "MN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 95.21619513758375,
#         "Humidity(%)": 59.470065907689595,
#         "Pressure(in)": 29.99,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-984853",
#         "Severity": 2,
#         "State": "FL",
#         "Timezone": "US/Central",
#         "Temperature(F)": 79.23700973060812,
#         "Humidity(%)": 29.63049605678883,
#         "Pressure(in)": 30.09,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-985950",
#         "Severity": 3,
#         "State": "OK",
#         "Timezone": "US/Central",
#         "Temperature(F)": 94.15217267676138,
#         "Humidity(%)": 64.28407461344318,
#         "Pressure(in)": 30.2,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-986103",
#         "Severity": 3,
#         "State": "OR",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 89.29157680593262,
#         "Humidity(%)": 58.04808775051759,
#         "Pressure(in)": 32.13121900038579,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-987162",
#         "Severity": 3,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 86.0,
#         "Humidity(%)": 42.0,
#         "Pressure(in)": 30.01,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-987491",
#         "Severity": 3,
#         "State": "KY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 95.0,
#         "Humidity(%)": 52.0,
#         "Pressure(in)": 29.93,
#         "Visibility(mi)": 6.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-988091",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 88.0,
#         "Humidity(%)": 49.0,
#         "Pressure(in)": 29.91,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-988733",
#         "Severity": 3,
#         "State": "TN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 89.20342558912243,
#         "Humidity(%)": 68.05303633854771,
#         "Pressure(in)": 30.01,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-989018",
#         "Severity": 3,
#         "State": "CO",
#         "Timezone": "US/Mountain",
#         "Temperature(F)": 90.24995440903746,
#         "Humidity(%)": 55.0,
#         "Pressure(in)": 34.97534083350468,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-989617",
#         "Severity": 2,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 87.0,
#         "Humidity(%)": 62.0,
#         "Pressure(in)": 29.91,
#         "Visibility(mi)": 6.0,
#         "Crossing": "True",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-98972",
#         "Severity": 2,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 75.70220220404657,
#         "Humidity(%)": 49.22287218231271,
#         "Pressure(in)": 31.60875919766603,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "True",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-989981",
#         "Severity": 4,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 86.0,
#         "Humidity(%)": 54.0,
#         "Pressure(in)": 31.29,
#         "Visibility(mi)": 3.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-990268",
#         "Severity": 3,
#         "State": "FL",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 82.0,
#         "Humidity(%)": 48.0,
#         "Pressure(in)": 29.67,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-991631",
#         "Severity": 3,
#         "State": "WA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 91.6525706299565,
#         "Humidity(%)": 41.259859815865624,
#         "Pressure(in)": 31.948200003991328,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-992411",
#         "Severity": 2,
#         "State": "TN",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 84.0,
#         "Humidity(%)": 67.0,
#         "Pressure(in)": 30.1,
#         "Visibility(mi)": 9.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-993020",
#         "Severity": 2,
#         "State": "SC",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 90.0,
#         "Humidity(%)": 62.0,
#         "Pressure(in)": 30.13,
#         "Visibility(mi)": 8.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "True",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-993072",
#         "Severity": 3,
#         "State": "GA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 95.0,
#         "Humidity(%)": 47.0,
#         "Pressure(in)": 30.06,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-993281",
#         "Severity": 3,
#         "State": "MN",
#         "Timezone": "US/Central",
#         "Temperature(F)": 100.27037363150791,
#         "Humidity(%)": 60.28909020718624,
#         "Pressure(in)": 30.0,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-99329",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 96.84548959460815,
#         "Humidity(%)": 45.69669738611799,
#         "Pressure(in)": 31.390412719468127,
#         "Visibility(mi)": 3.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Night"
#     },
#     {
#         "ID": "A-996589",
#         "Severity": 3,
#         "State": "CA",
#         "Timezone": "US/Pacific",
#         "Temperature(F)": 82.89866254852068,
#         "Humidity(%)": 37.11782993625894,
#         "Pressure(in)": 31.211791613630908,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-996885",
#         "Severity": 2,
#         "State": "MI",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 80.0,
#         "Humidity(%)": 64.0,
#         "Pressure(in)": 30.23,
#         "Visibility(mi)": 7.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-997522",
#         "Severity": 3,
#         "State": "VA",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 83.0,
#         "Humidity(%)": 44.0,
#         "Pressure(in)": 30.07,
#         "Visibility(mi)": 5.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     },
#     {
#         "ID": "A-999458",
#         "Severity": 4,
#         "State": "NY",
#         "Timezone": "US/Eastern",
#         "Temperature(F)": 103.0,
#         "Humidity(%)": 77.0,
#         "Pressure(in)": 31.03,
#         "Visibility(mi)": 4.0,
#         "Crossing": "False",
#         "Stop": "False",
#         "Traffic_Signal": "False",
#         "Sunrise_Sunset": "Day"
#     }
# ]

# %%
# Q1

attr = ["US/Central", "US/Eastern", "US/Mountain", "US/Pacific"]

# Building lists for each individual category
temp_means = []
temp_stds = []
humidity_means = []
humidity_stds = []
pressure_means = []
pressure_stds = []
visibility_means = []
visibility_stds = []

# using bar charts to visualize means and standard deviations of 
# Temperature(F), Humidity(%), Pressure(in), and Visibility(mi) values of different time zones
for zone in attr:
    temp = [j["Temperature(F)"] for j in data if j["Timezone"] == zone]
    temp_means.append(np.mean(temp))
    temp_stds.append(np.std(temp, ddof = 1))
    
    humidity = [j["Humidity(%)"] for j in data if j["Timezone"] == zone]
    humidity_means.append(np.mean(humidity))
    humidity_stds.append(np.std(humidity, ddof = 1))
    
    pressure = [j["Pressure(in)"] for j in data if j["Timezone"] == zone]
    pressure_means.append(np.mean(pressure))
    pressure_stds.append(np.std(pressure, ddof = 1))
    
    visibility = [j["Visibility(mi)"] for j in data if j["Timezone"] == zone]
    visibility_means.append(np.mean(visibility))
    visibility_stds.append(np.std(visibility, ddof = 1))

# Plotting the graphs
plt.figure(figsize = (20, 4))
plt.subplot(1, 4, 1)
plt.bar(attr, temp_means, yerr = temp_stds, color = 'darkorange', capsize = 10, width = 0.3)
plt.xticks()
plt.ylabel ("Temperature(F)")

plt.subplot(1, 4, 2)
plt.bar(attr, humidity_means, yerr = humidity_stds, color = 'green', capsize = 10, width = 0.3)
plt.xticks()
plt.ylabel ("Humidity(%)")

plt.subplot(1, 4, 3)
plt.bar(attr, pressure_means, yerr = pressure_stds, color = 'red', capsize = 10, width = 0.3)
plt.xticks()
plt.ylabel ("Pressure(in)")

plt.subplot(1, 4, 4)
plt.bar(attr, visibility_means, yerr = visibility_stds, color = 'purple', capsize = 10, width = 0.3)
plt.xticks()
plt.ylabel ("Visibility(mi)")
plt.savefig("question1.png")

# create a list that will hold our dictionary
result = []
for i, zone in enumerate(attr):
    answer_dict = {
        'TimeZone': zone,
        'Temperature(F)_mean': temp_means[i],
        'Temperature(F)_std': temp_stds[i],
        'Humidity(%)_mean': humidity_means[i],
        'Humidity(%)_std': humidity_stds[i],
        'Pressure(in)_mean': pressure_means[i],
        'Pressure(in)_std': pressure_stds[i],
        'Visibility(mi)_mean': visibility_means[i],
        'Visibility(mi)_std': visibility_stds[i]
    }
    result.append(answer_dict)
result

with open("question1.csv", encoding = "utf-8", mode = 'w') as csv_result:
    csv_writer = csv.writer(csv_result, 
                            delimiter = ",", # seperates every value with a comma
                            quotechar = '"', # puts a quote around multiple same ones
                            quoting = csv.QUOTE_MINIMAL, 
                            lineterminator = "\n")
    csv_writer.writerow(result[0].keys())
    for d in result:
        csv_writer.writerow(d.values())

# %%
# Q2

# Visualize a scatter plot of temp vs humidity of the top 3 states with the most accidents
def q2_visual(ps):
    colors = ["blue", "orange", "green"]
    correlations = []
    plt.figure(figsize = (20, 16))
    plt.subplot(1, 1, 1) # first # - row, second # - column, third # - order in which it is shown
    for i, (state_name, accident_count) in enumerate(ps.items()):
        th_element = [(d["Temperature(F)"], d["Humidity(%)"]) for d in data if d["State"] == state_name]
        corr_mtx = np.corrcoef([d[0] for d in th_element], [d[1] for d in th_element])
        plt.scatter([g[0] for g in th_element], [g[1] for g in th_element], s = 50, c = colors[i], marker = "+", alpha = 0.5, label = state_name)
        correlations.append(corr_mtx)
        
    plt.legend()
    plt.xlabel("Temperature(F)")
    plt.ylabel("Humidity(%)")
    #plt.show()
    plt.savefig("question2.png")
    return correlations
    

# Get all the states and put them in a list
states = [d["State"] for d in data]

# Create a (state:count) dictionary
state_dict = Counter(states)

# popular_states will be a dict of 3 top states with their accident count numbers
popular_states = {k: v for k, v in sorted(state_dict.items(), key = lambda item: item[1], reverse = True)[:3]}

# calling the function that plots the graph for us, 
#outputs correlation values for the top three states as well
correlation = q2_visual(popular_states)

# create a list that will hold our dictionary
statesdict_list = []
for i, (k, v) in enumerate(popular_states.items()):
    states_dict = {"State": k, "Accident": v, "Correlation": correlation[i][0][1]}
    statesdict_list.append(states_dict)
    
print(statesdict_list)

# with open("question2.csv", encoding = "utf-8", mode = 'w') as csv_result:
#     csv_writer = csv.writer(csv_result, 
#                             delimiter = ",", # seperates every value with a comma
#                             quotechar = '"', # puts a quote around multiple same ones
#                             quoting = csv.QUOTE_MINIMAL, 
#                             lineterminator = "\n")
#     csv_writer.writerow(statesdict_list[0].keys())
#     for d in statesdict_list:
#         csv_writer.writerow(d.values())
# Out:
# [{'State': 'CA', 'Accident': 825, 'Correlation': 0.38716339596974647}, {'State': 'TX', 'Accident': 379, 'Correlation': 0.38936632725972137}, {'State': 'FL', 'Accident': 356, 'Correlation': 0.40221999119199264}]

# %%
# Q3

def q3_visual(al):
    
    # Building the lists that will contain the appropriate values
    state_values = []
    crossing_values = []
    stop_values = []
    traffic_signals = []
    
    # Appending the appropriate values into each of the above lists
    for d in al:
        state_values.append(d["State"]) # x
        crossing_values.append(d["Crossing"]) # y1
        stop_values.append(d["Stop"]) # y2
        traffic_signals.append(d["Traffic_Signal"]) # y3
    
    x_values = range(len(state_values))
    
    # Creating the graph
    w = 0.2
    plt.figure(figsize = (20, 8))
    plt.bar([x - 0.8 * w for x in x_values], crossing_values, color = "blue", width = w, label = "Crossing")
    plt.bar([x + 0.2 * w for x in x_values], stop_values, color = "orange", width = w, label = "Stop")
    plt.bar([x + 1.2 * w for x in x_values], traffic_signals, color = "green", width = w, label = "Traffic_Signal")

    x_ticks = state_values
    plt.xticks(x_values, x_ticks)
    plt.ylim(0, 100)
    plt.legend(loc = "best")
    plt.yticks(np.arange(0, 120, 20))
    plt.xlabel("States")
    plt.ylabel("Percentage")

    # Saving the graph
    plt.savefig('question3.png')

from collections import Counter

# Get all the states and put them in a list
states = [d["State"] for d in data]
state_dict = Counter(states)

state_accident = {k: v for k, v in sorted(state_dict.items(), key = lambda item: item[0], reverse = False)}

state_accident

# building state:accident dictionary
accidents_list = []
for state_name, state_count in state_accident.items():
    crossings = len([d["Crossing"] for d in data if d["Crossing"] == "True" and d["State"] == state_name])/state_count 
    stop = len([d["Stop"] for d in data if d["Stop"] == "True" and d["State"] == state_name])/state_count
    traffic_signals = len([d["Traffic_Signal"] for d in data if d["Traffic_Signal"] == "True" and d["State"] == state_name])/state_count
    
    accidents_prob = {"State": state_name, "Crossing": crossings * 100, "Stop": stop * 100, "Traffic_Signal": traffic_signals * 100}
    accidents_list.append(accidents_prob)

accidents_list

# Calling Visualization graph
q3_visual(accidents_list)

with open("question3.csv", encoding = "utf-8", mode = 'w') as csv_result:
    csv_writer = csv.writer(csv_result, 
                            delimiter = ",", # seperates every value with a comma
                            quotechar = '"', # puts a quote around multiple same ones
                            quoting = csv.QUOTE_MINIMAL, 
                            lineterminator = "\n")
    csv_writer.writerow(accidents_list[0].keys())
    for d in accidents_list:
        csv_writer.writerow(d.values())

# %%
#Q4 all your answers to Q4 must be only in this cell.

def q4_visual():
    
    # Creating four lists that will hold the values for severity 1, 2, 3 and 4
    severity1 = [d for d in data if d["Severity"] == 1]
    severity2 = [d for d in data if d["Severity"] == 2]
    severity3 = [d for d in data if d["Severity"] == 3]
    severity4 = [d for d in data if d["Severity"] == 4]

    plt.figure(figsize = (30, 8))

    temp_dict = [{"Severity": severity1, "Color": 'b-', "Label": "Severity-1"},
                 {"Severity": severity2, "Color": 'orange', "Label": "Severity-2"}, 
                 {"Severity": severity3, "Color": 'g-', "Label": "Severity-3"}, 
                 {"Severity": severity4, "Color": 'r-', "Label": "Severity-4"}]

    plt.subplot(1, 3, 1)
    xs = np.arange(70, 110, 0.5)
    for td in temp_dict: 
        mean = np.mean([d["Temperature(F)"] for d in td["Severity"]])
        std = np.std([d["Temperature(F)"] for d in td["Severity"]], ddof = 1)
        plt.plot(xs, norm.pdf(xs, mean, std), td["Color"], label = td["Label"])
    plt.legend(loc = 'upper left')
    plt.title("Temperature(F)")
    
    plt.subplot(1, 3, 2)
    xs = np.arange(20, 80, 1)
    for td in temp_dict: 
        mean = np.mean([d["Humidity(%)"] for d in td["Severity"]])
        std = np.std([d["Humidity(%)"] for d in td["Severity"]], ddof = 1)
        plt.plot(xs, norm.pdf(xs, mean, std), td["Color"], label = td["Label"])
    plt.legend(loc = 'upper left')
    plt.title("Humidity(%)")
    
    plt.subplot(1, 3, 3)
    xs = np.arange(0, 10, 0.1)
    for td in temp_dict: 
        mean = np.mean([d["Visibility(mi)"] for d in td["Severity"]])
        std = np.std([d["Visibility(mi)"] for d in td["Severity"]], ddof = 1)
        plt.plot(xs, norm.pdf(xs, mean, std), td["Color"], label = td["Label"])
    plt.legend(loc = 'upper left')
    plt.title("Visibility(mi)")
    
    #plt.show()
    plt.savefig('question4.png')
    
# calling the visualization function
q4_visual()


# E = S4
# F = (t, h, v)
# P(E|F) = (((P(F|E) * P(E))/P(F))
# P(S4|t, h, v) = P((t, h, v)|S4) * P(S4)/P(t, h, v)
# P(S4|t, h, v) = (P(t|S4) * P(h|S4) * P(v|S4)) * P(S4) / (P(t) * P(h) * P(v))

def q4_ProbOfAccidentForS4GivenX(temp, humidityLow, humidityHigh, visibility):
    accidents_s4 = [d for d in data if d["Severity"] == 4]
    # P(t|S4)
    temp_mean = np.mean([d["Temperature(F)"] for d in accidents_s4])
    temp_std = np.std([d["Temperature(F)"] for d in accidents_s4], ddof = 1)
    p_TempgivenS4 = norm.pdf(temp, temp_mean, temp_std)
    
    # P(h|S4)
    humidity_mean = np.mean([d["Humidity(%)"] for d in accidents_s4])
    humidity_std = np.std([d["Humidity(%)"] for d in accidents_s4], ddof = 1)
    p_HumiditygivenS4 = norm.cdf(humidityHigh, humidity_mean, humidity_std) - norm.cdf(humidityLow, humidity_mean, humidity_std)
    
    #P(v|S4)
    visibility_mean = np.mean([d["Visibility(mi)"] for d in data])
    visibility_std = np.std([d["Visibility(mi)"] for d in data], ddof = 1)
    p_VisibilitygivenS4 = norm.pdf(visibility, visibility_mean, visibility_std)
    
    #P(S4)
    p_S4 = len(accidents_s4)/len(data)
    
    #P(t)
    temp_mean = np.mean([d["Temperature(F)"] for d in data])
    temp_std = np.std([d["Temperature(F)"] for d in data], ddof = 1)
    p_Temp = norm.pdf(temp, temp_mean, temp_std)
    
    #P(h)
    humidity_mean = np.mean([d["Humidity(%)"] for d in data])
    humidity_std = np.std([d["Humidity(%)"] for d in data], ddof = 1)
    p_Humidity = norm.cdf(humidityHigh, humidity_mean, humidity_std) - norm.cdf(humidityLow, humidity_mean, humidity_std)
    
    #P(v)
    visibility_mean = np.mean([d["Visibility(mi)"] for d in data])
    visibility_std = np.std([d["Visibility(mi)"] for d in data], ddof = 1)
    p_Visibility = norm.pdf(visibility, visibility_mean, visibility_std)
    
    # P(S4|t, h, v) = P((t, h, v)|S4) * P(S4)/P(t, h, v)
    probOfAccidentForS4GivenX = ((p_TempgivenS4 * p_HumiditygivenS4 * p_VisibilitygivenS4 * p_S4) / (p_Temp * p_Humidity * p_Visibility))
    return probOfAccidentForS4GivenX

final_answer = q4_ProbOfAccidentForS4GivenX(90, 60, 70, 4)

answer_dict = [{"answer": final_answer}]

with open("question4.csv", encoding = "utf-8", mode = 'w') as csv_result:
    csv_writer = csv.writer(csv_result, 
                            delimiter = ",", # seperates every value with a comma
                            quotechar = '"', # puts a quote around multiple same ones
                            quoting = csv.QUOTE_MINIMAL,
                            lineterminator = "\n")
    csv_writer.writerow(answer_dict[0].keys())
    for d in answer_dict:
        csv_writer.writerow(d.values())

# %%
# Q5

accidents = 100
target_severity = 60
target_day = 70
p_S1orS2 = len([d["Severity"] for d in data if d["Severity"] == 1 or d["Severity"] == 2])/len(data)
#print(p_S1orS2)
p_Day = len([d["Sunrise_Sunset"] for d in data if d["Sunrise_Sunset"] == "Day"])/len(data)
#print(p_Day)
p_60_s1_s2 = 1 - binom.cdf(target_severity, accidents, p_S1orS2)
p_70_day = 1 - binom.cdf(target_day, accidents, p_Day)
final_result = p_60_s1_s2 * p_70_day * 100

answer_dict = [{"answer": final_result}]

with open("question5.csv", encoding = "utf-8", mode = 'w') as csv_result:
    csv_writer = csv.writer(csv_result, 
                            delimiter = ",", # seperates every value with a comma
                            quotechar = '"', # puts a quote around multiple same ones
                            quoting = csv.QUOTE_MINIMAL, 
                            lineterminator = "\n")
    csv_writer.writerow(answer_dict[0].keys())
    for d in answer_dict:
        csv_writer.writerow(d.values())

# %%
# Q6

# E = S1 or (S2 or S3 or S4)
# F = (t, v, s)
# P(E|F) = (((P(F|E) * P(E))/P(F))
# P(S|t, v, s) = P((t, v, s)|S) * P(S)
# P(S|t, v, s) = (P(t|S) * P(v|S) * P(s|S)) * P(S)

# Calculates factor of severity given an X value by taking in 3 parameters for a specified severity, where
# accidents is a list of records for a specified severity
def q6_factor_of_severity_given_X(accidents, temp, visibility, sun):
    temp_list = []
    visibility_list = []
    sun_list = []
    
    # Builds 3 lists in one loop to optimize for performance
    for d in accidents:
        temp_list.append(d["Temperature(F)"])
        visibility_list.append(d["Visibility(mi)"])
        if (d["Sunrise_Sunset"] == sun):
            sun_list.append(d["Sunrise_Sunset"])
            
    
    # P(t|S)
    temp_mean = np.mean(temp_list)
    temp_std = np.std(temp_list, ddof = 1)
    p_TempgivenS = norm.pdf(temp, temp_mean, temp_std)
    
    #P(v|S)
    visibility_mean = np.mean(visibility_list)
    visibility_std = np.std(visibility_list, ddof = 1)
    p_VisibilitygivenS = norm.pdf(visibility, visibility_mean, visibility_std)
    
    #P(s|S)
    p_SungivenS = len(sun_list)/len(accidents)
    
    #P(S)
    p_S = len(accidents)/len(data)
    
    # Final equation to get factor of severity for a given x
    factorOfSeverityForGivenX = p_TempgivenS * p_VisibilitygivenS * p_SungivenS * p_S
    
    return factorOfSeverityForGivenX

# Finds the index of the largest value: 1, 2, 3 or 4
def findMax(a1, a2, a3, a4):
    # Check for which given numbers is the largest and assign it to "a"
    a = a1
    if (a < a2):
        a = a2
    if (a < a3):
        a = a3
    if (a < a4):
        a = a4
    
    # Returns number for largest "a"
    if (a == a1):
        return 1
    if (a == a2):
        return 2
    if (a == a3):
        return 3
    if (a == a4):
        return 4

# Returns the most likely severity given X: temp, visibility, sun.
def q6_naive_bayes_classifier(temp, visibility, sun):
    accidentsGivenSeverity1 = []
    accidentsGivenSeverity2 = []
    accidentsGivenSeverity3 = []
    accidentsGivenSeverity4 = []
    
    # create four lists holding values for severity 1, 2, 3, 4
    for d in data:
        if (d["Severity"] == 1):
            accidentsGivenSeverity1.append(d)
        if (d["Severity"] == 2):
            accidentsGivenSeverity2.append(d)
        if (d["Severity"] == 3):
            accidentsGivenSeverity3.append(d)
        if (d["Severity"] == 4):
            accidentsGivenSeverity4.append(d)
    
    # Gets the values for each severity level
    s1 = q6_factor_of_severity_given_X(accidentsGivenSeverity1, temp, visibility, sun)
    s2 = q6_factor_of_severity_given_X(accidentsGivenSeverity2, temp, visibility, sun)
    s3 = q6_factor_of_severity_given_X(accidentsGivenSeverity3, temp, visibility, sun)
    s4 = q6_factor_of_severity_given_X(accidentsGivenSeverity4, temp, visibility, sun)
    
    # returns the index of the largest value: 1, 2, 3 or 4
    return findMax(s1, s2, s3, s4)

# Create our dictionary to prepare to put everything into a CSV file
severity_list = []
for d in test:
    severity_prediction = {"ID": d["ID"], "prediction": q6_naive_bayes_classifier(d["Temperature(F)"], d["Visibility(mi)"], d["Sunrise_Sunset"])}
    severity_list.append(severity_prediction)

# Create our CSV file
with open("question6.csv", encoding = "utf-8", mode = 'w') as csv_result:
    csv_writer = csv.writer(csv_result, 
                            delimiter = ",", # seperates every value with a comma
                            quotechar = '"', # puts a quote around multiple same ones
                            quoting = csv.QUOTE_MINIMAL, 
                            lineterminator = "\n")
    csv_writer.writerow(severity_list[0].keys())
    for d in severity_list:
        csv_writer.writerow(d.values())
# Out:
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# ...
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# 0.007717750826901874
# 0.4410143329658214
# 0.33076074972436603
# 0.2205071664829107
# --------------------------------------------------------------------
# PermissionError                    Traceback (most recent call last)
# <ipython-input-7-1df3b350799d> in <module>
#      98
#      99 # Create our CSV file
# --> 100 with open("question6.csv", encoding = "utf-8", mode = 'w') as csv_result:
#     101     csv_writer = csv.writer(csv_result,
#     102                             delimiter = ",", # seperates every value with a comma
#
# PermissionError: [Errno 13] Permission denied: 'question6.csv'
